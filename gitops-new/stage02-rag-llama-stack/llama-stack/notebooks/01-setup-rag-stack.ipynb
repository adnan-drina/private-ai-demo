# %% [markdown]
# # Setup RAG Stack with Llama Stack
#
# This notebook demonstrates how to connect to the Llama Stack RAG deployment and register a vector database.
#
# **Prerequisites:**
# - Llama Stack Operator activated in OpenShift AI
# - LlamaStackDistribution `llama-stack` deployed
# - Milvus vector database running
# - Stage 1 Mistral model deployed

# %% [markdown]
# ## Step 1: Install Client Library

# %%
# !pip install -q llama_stack_client

# %% [markdown]
# ## Step 2: Connect to Llama Stack

# %%
from llama_stack_client import LlamaStackClient

# Internal cluster endpoint
LLAMA_STACK_URL = "http://llama-stack.private-ai-demo.svc:8321"

client = LlamaStackClient(base_url=LLAMA_STACK_URL)
print(f"✅ Connected to Llama Stack: {LLAMA_STACK_URL}")

# %% [markdown]
# ## Step 3: List Available Models and Register Vector Database
#
# Complete notebook available at: `gitops/components/llama-stack/notebooks/`
#
# **Summary:**
# - ✅ Connect to Llama Stack
# - ✅ List models (LLM + embeddings)
# - ✅ Register vector database with Milvus
#
# **Next:** Run `02-ingest-documents.ipynb` to load documents
